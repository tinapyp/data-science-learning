# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='density', figsize=(20,9))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales.Order_Quantity.mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].mean()

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
sales['Order_Quantity'].plot(kind='box', vert=False ,figsize=(20,9))
# Out:
# <Axes: >

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist', bins=20 ,figsize=(20,9))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].value_counts()
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
sales['Year'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
sales['Year'].value_counts().plot(kind='pie', figsize=(10,6))
# Out:
# <Axes: ylabel='Year'>

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales['Month'].value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %%
sales['Month'].value_counts()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar', fontsize=(20,9))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # your code goes here
# ----> 2 sales['Month'].value_counts().plot(kind='bar', fontsize=(20,9))
#
# File ~/Dependencies/miniconda3/lib/python3.9/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Dependencies/miniconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/Dependencies/miniconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:458, in MPLPlot.generate(self)
#     455 self._adorn_subplots()
#     457 for ax in self.axes:
# --> 458     self._post_plot_logic_common(ax, self.data)
#     459     self._post_plot_logic(ax, self.data)
#
# File ~/Dependencies/miniconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:655, in MPLPlot._post_plot_logic_common(self, ax, data)
#     653 """Common post process for each axes"""
#     654 if self.orientation == "vertical" or self.orientation is None:
# --> 655     self._apply_axis_properties(ax.xaxis, rot=self.rot, fontsize=self.fontsize)
#     656     self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     658     if hasattr(ax, "right_ax"):
#
# File ~/Dependencies/miniconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:749, in MPLPlot._apply_axis_properties(self, axis, rot, fontsize)
#     747     label.set_rotation(rot)
#     748 if fontsize is not None:
# --> 749     label.set_fontsize(fontsize)
#
# File ~/Dependencies/miniconda3/lib/python3.9/site-packages/matplotlib/text.py:1110, in Text.set_fontsize(self, fontsize)
#    1095 def set_fontsize(self, fontsize):
#    1096     """
#    1097     Set the font size.
#    1098
#    (...)
#    1108     .font_manager.FontProperties.set_size
#    1109     """
# -> 1110     self._fontproperties.set_size(fontsize)
#    1111     self.stale = True
#
# File ~/Dependencies/miniconda3/lib/python3.9/site-packages/matplotlib/font_manager.py:828, in FontProperties.set_size(self, size)
#     826     size = mpl.rcParams['font.size']
#     827 try:
# --> 828     size = float(size)
#     829 except ValueError:
#     830     try:
#
# TypeError: float() argument must be a string or a number, not 'tuple'

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales['Country'].value_counts().head(1)
# Out:
# United States    39206
# Name: Country, dtype: int64

# %%
sales['Country'].value_counts().head(1)

# %%
sales['Country'].value_counts()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales['Country'].value_counts().plot(kind='bar', figsize=(20,9))
# Out:
# <Axes: >

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
sales.Product.unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
#        'Mountain-100 Silver, 42', 'Mountain-200 Black, 46',
#        'Mountain-200 Silver, 42', 'Mountain-200 Silver, 46',
#        'Mountain-200 Black, 38', 'Mountain-100 Black, 42',
#        'Mountain-200 Black, 42', 'Mountain-400-W Silver, 46',
#        'Mountain-500 Silver, 40', 'Mountain-500 Silver, 44',
#        'Mountain-500 Black, 48', 'Mountain-500 Black, 40',
#        'Mountain-400-W Silver, 42', 'Mountain-500 Silver, 52',
#        'Mountain-500 Black, 52', 'Mountain-500 Silver, 42',
#        'Mountain-500 Black, 44', 'Mountain-500 Silver, 48',
#        'Mountain-400-W Silver, 38', 'Mountain-400-W Silver, 40',
#        'Mountain-500 Black, 42', 'Road-150 Red, 48', 'Road-150 Red, 62',
#        'Road-750 Black, 48', 'Road-750 Black, 58', 'Road-750 Black, 52',
#        'Road-150 Red, 52', 'Road-150 Red, 44', 'Road-150 Red, 56',
#        'Road-750 Black, 44', 'Road-350-W Yellow, 40',
#        'Road-350-W Yellow, 42', 'Road-250 Black, 44',
#        'Road-250 Black, 48', 'Road-350-W Yellow, 48',
#        'Road-550-W Yellow, 44', 'Road-550-W Yellow, 38',
#        'Road-250 Black, 52', 'Road-550-W Yellow, 48', 'Road-250 Red, 58',
#        'Road-250 Black, 58', 'Road-250 Red, 52', 'Road-250 Red, 48',
#        'Road-250 Red, 44', 'Road-550-W Yellow, 42',
#        'Road-550-W Yellow, 40', 'Road-650 Red, 48', 'Road-650 Red, 60',
#        'Road-650 Black, 48', 'Road-350-W Yellow, 44', 'Road-650 Red, 52',
#        'Road-650 Black, 44', 'Road-650 Red, 62', 'Road-650 Red, 58',
#        'Road-650 Black, 60', 'Road-650 Black, 58', 'Road-650 Black, 52',
#        'Road-650 Black, 62', 'Road-650 Red, 44',
#        "Women's Mountain Shorts, M", "Women's Mountain Shorts, S",
#        "Women's Mountain Shorts, L", 'Racing Socks, L', 'Racing Socks, M',
#        'Mountain Tire Tube', 'Touring Tire Tube', 'Patch Kit/8 Patches',
#        'HL Mountain Tire', 'LL Mountain Tire', 'Road Tire Tube',
#        'LL Road Tire', 'Touring Tire', 'ML Mountain Tire', 'HL Road Tire',
#        'ML Road Tire', 'Touring-1000 Yellow, 50', 'Touring-1000 Blue, 46',
#        'Touring-1000 Yellow, 60', 'Touring-1000 Blue, 50',
#        'Touring-3000 Yellow, 50', 'Touring-3000 Blue, 54',
#        'Touring-3000 Blue, 58', 'Touring-3000 Yellow, 44',
#        'Touring-3000 Yellow, 54', 'Touring-3000 Blue, 62',
#        'Touring-3000 Blue, 44', 'Touring-1000 Blue, 54',
#        'Touring-1000 Yellow, 46', 'Touring-1000 Blue, 60',
#        'Touring-3000 Yellow, 62', 'Touring-1000 Yellow, 54',
#        'Touring-2000 Blue, 54', 'Touring-3000 Blue, 50',
#        'Touring-3000 Yellow, 58', 'Touring-2000 Blue, 46',
#        'Touring-2000 Blue, 50', 'Touring-2000 Blue, 60',
#        'Classic Vest, L', 'Classic Vest, M', 'Classic Vest, S'],
#       dtype=object)

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(20,9))
# Out:
# <Axes: >

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here
sales['Calculated_Date'] = (sales[['Year', 'Month', 'Day']]).apply(lambda x: f"{x[0]}-{x[1]}-{x[2]}", axis=1)
sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales['Revenue'] += 50

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# sales.loc[(sales['Country']=='Canada') | (sales['Country'] == 'France')]

sales.loc[sales['Country'].isin(['Canada', 'France'])]
# Out:
#              Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0      2013-11-26   26   November  2013            19           Youth (<25)
# 1      2015-11-26   26   November  2015            19           Youth (<25)
# 14     2013-08-02    2     August  2013            29  Young Adults (25-34)
# 15     2015-08-02    2     August  2015            29  Young Adults (25-34)
# 16     2013-09-02    2  September  2013            29  Young Adults (25-34)
# ...           ...  ...        ...   ...           ...                   ...
# 112979 2015-09-08    8  September  2015            31  Young Adults (25-34)
# 113000 2014-07-27   27       July  2014            34  Young Adults (25-34)
# 113001 2016-07-27   27       July  2016            34  Young Adults (25-34)
# 113034 2014-03-04    4      March  2014            37        Adults (35-64)
# 113035 2016-03-04    4      March  2016            37        Adults (35-64)
#
#        Customer_Gender Country             State Product_Category  \
# 0                    M  Canada  British Columbia      Accessories
# 1                    M  Canada  British Columbia      Accessories
# 14                   M  Canada  British Columbia      Accessories
# 15                   M  Canada  British Columbia      Accessories
# 16                   M  Canada  British Columbia      Accessories
# ...                ...     ...               ...              ...
# 112979               M  France           Essonne         Clothing
# 113000               M  France           Essonne         Clothing
# 113001               M  France           Essonne         Clothing
# 113034               F  France     Seine (Paris)         Clothing
# 113035               F  France     Seine (Paris)         Clothing
#
#        Sub_Category              Product  Order_Quantity  Unit_Cost  \
# 0        Bike Racks  Hitch Rack - 4-Bike               8         45
# 1        Bike Racks  Hitch Rack - 4-Bike               8         45
# 14       Bike Racks  Hitch Rack - 4-Bike               5         45
# 15       Bike Racks  Hitch Rack - 4-Bike               7         45
# 16       Bike Racks  Hitch Rack - 4-Bike               2         45
# ...             ...                  ...             ...        ...
# 112979        Vests      Classic Vest, M              28         24
# 113000        Vests      Classic Vest, M               6         24
# 113001        Vests      Classic Vest, M               7         24
# 113034        Vests      Classic Vest, L              24         24
# 113035        Vests      Classic Vest, L              23         24
#
#         Unit_Price  Profit  Cost  Revenue Calculated_Date
# 0              120     590   360     1000      2013-11-26
# 1              120     590   360     1000      2015-11-26
# 14             120     369   225      644      2013-08-02
# 15             120     517   315      882      2015-08-02
# 16             120     148    90      288      2013-09-02
# ...            ...     ...   ...      ...             ...
# 112979          64    1048   672     1770      2015-09-08
# 113000          64     225   144      419      2014-07-27
# 113001          64     262   168      480      2016-07-27
# 113034          64     684   576     1310      2014-03-04
# 113035          64     655   552     1257      2016-03-04
#
# [25176 rows x 19 columns]

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales.loc[(sales['Sub_Category'] == 'Bike Racks') & (sales['Country'] == 'Canada')].shape[0]
# Out:
# 104

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
france_sales = sales.loc[sales['Country'] == 'France', 'State'].value_counts() ; france_sales
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
france_sales.plot(kind='bar', figsize=(10,6))
# Out:
# <Axes: >

# %%
france_states.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales.Product_Category.value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
sales['Product_Category'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sales.Product_Category.value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='Product_Category'>

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
sales.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue', 'Calculated_Date'],
#       dtype='object')

# %%
# your code goes here
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts() ;accessories
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
accessories.plot(kind='bar', figsize=(10,6))
# Out:
# <Axes: >

# %%
accessories.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts() ;bikes
# Out:
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: Sub_Category, dtype: int64

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
bikes.plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='Sub_Category'>

# %%
bikes.plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
sales.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue', 'Calculated_Date'],
#       dtype='object')

# %%
# your code goes here
sales['Customer_Gender'].value_counts().head(1)
# Out:
# M    58312
# Name: Customer_Gender, dtype: int64

# %%
sales['Customer_Gender'].value_counts()

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here
sales.loc[(sales['Revenue'] > 500) & (sales['Customer_Gender'] == 'M')].shape[0]
# Out:
# 23342

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
sales.sort_values(['Revenue'],ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# 112073        Vests  Touring-1000 Yellow, 50              29       1482
# 112072        Vests  Touring-1000 Yellow, 50              27       1482
# 71129    Road Bikes         Road-150 Red, 48               4       2171
# 70307    Road Bikes         Road-150 Red, 62               4       2171
# 70601    Road Bikes         Road-150 Red, 62               4       2171
#
#         Unit_Price  Profit   Cost  Revenue Calculated_Date
# 112073        2384   15096  42978    58124      2015-07-24
# 112072        2384   14055  40014    54119      2013-07-24
# 71129         3578    5628   8684    14362      2011-07-08
# 70307         3578    5485   8684    14219      2011-04-30
# 70601         3578    5485   8684    14219      2011-09-30

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
sales.loc[sales['Revenue'] == sales['Revenue'].max()]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58124      2015-07-24

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
sales.loc[sales['Order_Quantity'] > 10_000, 'Order_Quantity'].mean()
# Out:
# nan

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
sales.loc[sales['Revenue'] < 10_000, 'Order_Quantity'].mean()
# Out:
# 11.914539380997528

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914539380997528

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
sales.loc[(sales['Month'].isin(['May','June','July'])) & (sales['Year'] == 2016)].shape[0]
# Out:
# 12164

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here
profit_Q32016 = sales.loc[cond, ['Profit', 'Month']]

profit_Q32016.boxplot(by='Month', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here
sales.loc[sales['Country'] == 'United States','Unit_Price'] *= 1.72

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
