# %%
import pandas as pd

# %% [markdown]
# ## Importing Dataset

# %%
music_df = pd.read_csv('data/music_love_by_ages/music.csv') ;df.head()
# Out:
#    age  gender   genre
# 0   20       1  HipHop
# 1   23       1  HipHop
# 2   25       1  HipHop
# 3   26       1    Jazz
# 4   29       1    Jazz

# %%
music_df.shape
# Out:
# (18, 3)

# %% [markdown]
# ## Prepare the data

# %%
X = music_df.drop('genre', axis=1)
y = music_df['genre']

# %%
# Train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Create Model and Training

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Test the model
model.predict([[21, 1], [20, 0]])
# Out:
# /home/tinapyp/Dependencies/miniconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %% [markdown]
# ## Evaluate the model

# %%
predictions = model.predict(X_test)

# %%
y_test
# Out:
# 4          Jazz
# 15    Classical
# 10        Dance
# 12     Acoustic
# Name: genre, dtype: object

# %%
score = accuracy_score(y_test, predictions)
print('accuracy_score: ', score)
# Out:
# accuracy_score:  1.0

# %% [markdown]
# ## Save and load model

# %%
import joblib

# Save model using joblib
joblib.dump(model, 'models/music-recommender.joblib')
# Out:
# ['models/music-recommender.joblib']

# %%
import joblib

# Load model using joblib
model = joblib.load('models/music-recommender.joblib')

# %% [markdown]
# ## Visualize the Decision Tree

# %%
from sklearn import tree

tree.export_graphviz(model, out_file='music-recommender.dot', \
    feature_names=music_df.columns[:-1], \
    class_names=sorted(y.unique()), \
    label='all', \
    rounded=True, \
    filled=True
)
